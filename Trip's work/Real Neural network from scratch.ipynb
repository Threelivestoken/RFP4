# %%
#install stuff for frogger game thing
# !pip install gymnasium
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %%
import gymnasium as gym
import random

# %%
enviros = gym.envs.registry
#for e in enviros.keys():
#    print(e)

# %%
env = gym.make('ALE/Frogger-v5', render_mode="human")
k=env.reset()

# %%
for taco in range(50):#steps until music is over
    env.step(0)
print("Done")
#move randomly 100 times
#for taco in range(100):
#    env.step(random.randint(1,4))
env.step(1)

# %%
#Installing stuff for neural network stuff

# %%
# !pip install tensorflow
# !pip install keras

# %%
import tensorflow as tf
import keras as ks

# %%
from keras.models import Sequential
from keras.layers import Convolution2D

# %%
model = Sequential()

# %%
height,width,channels=env.observation_space.shape

# %%
model.add(Convolution2D(4,(8,8),strides=(4,4),activation="relu",input_shape=("3")))
#,input_shape=(3),height=(3),width=(4))

# %%
l=1
e=0
for taco in range(1,100):
    e+=1/l
    l=l*taco
#print(e)
x=1
e=(1+1/100)**100
print((e**x-e**(-x))/(e**x+e**(-x)))

# %%
#neural network with nodes, the inputs, multipliers and bias for it
def createNN(nodes,layers,Numofconnections,Random):
    #check to prevent not matching length of nodes and the amount of layers
    if not type(nodes) in [int,list]:#check to see if the nodes should all be uniform/have the same value, this check is not done yet only started
        print("There are no valid node value(s)!")
    else:
        if type(nodes)== int:#check to see if its an int and then making the nodes variable into a list
            for taco in range(layers):
                if type(nodes)==int:
                    nodes=[nodes]
                else:
                    nodes.append(nodes[0])
        if len(nodes)<layers:
            print("Nodes<layers")
        else:
            
            exampleNN={
                "Nodes":nodes,#its a list of the different lengths
                "Layers":layers,
                #"1":["Current value","Bias","input","Multipliers"]
            }
            #make the empty layers
            for layer in range(layers):
                exampleNN["L"+str(layer)]=[]
                
            #fill the empty layers
            for layer in range(layers):
                for node in range(nodes[layer]):#going through the list
                    exampleNN["L"+str(layer)].append(0)
            
            return exampleNN
NN=createNN(6,4,3,0)
print(NN)
# Out:
# {'Nodes': [6, 6, 6, 6], 'Layers': 4, 'L0': [0, 0, 0, 0, 0, 0], 'L1': [0, 0, 0, 0, 0, 0], 'L2': [0, 0, 0, 0, 0, 0], 'L3': [0, 0, 0, 0, 0, 0]}

# %%
#unpackage view
#just testing out types of stuff
import seaborn as sns
import pandas as pd
import math

# %%
x=[0]
y=[0]
z=[]
it=0
lols=4
WidthAndHeight=2**lols
for taco in range(lols):
    #make temporary lists to use
    xtemp=[]
    ytemp=[]
    #reset the original lists
    
    
    for taco in range(len(x)):
        xtemp.append(y[taco])
        ytemp.append(x[taco])
    for taco in range(len(x)):
        xtemp.append(x[taco])
        ytemp.append(2**it+y[taco])
    for taco in range(len(x)):
        xtemp.append(2**it+x[taco])
        ytemp.append(2**it+y[taco])
    for taco in range(len(x)):
        xtemp.append(2**(it+1)-1-y[taco])
        ytemp.append(2**it-1-x[taco])
    x=xtemp
    y=ytemp
    
    #x1=(y0,x0,2**it+x0,2**(it+1)-1-y0)
    #y1=x0,2**it+y0,2**it+y0,2**it-1-x0
    it+=1
for taco in range(len(x)):
    z.append(taco)
data=pd.DataFrame({"x":x,"y":y,"z":z})
sns.histplot(data=data,x="x",y="y",hue="z",bins=2**(it-1))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#look at the data pandas dataframe
data
#make a new dictionary where you can index the x & y variables as a string with a | in the middle
temp_dictionary={}
for taco in range(len(data["x"])):
    temp_dictionary[str(data["x"][taco])+"|"+str(data["y"][taco])]=[data["z"][taco],0,0]#the first 0 is the value and the second is the second value

# %%
data
# Out:
#       x  y    z
# 0     0  0    0
# 1     1  0    1
# 2     1  1    2
# 3     0  1    3
# 4     0  2    4
# ..   .. ..  ...
# 251  15  2  251
# 252  15  1  252
# 253  14  1  253
# 254  14  0  254
# 255  15  0  255
#
# [256 rows x 3 columns]

# %%
temp_dictionary
# Out:
# {'0|0': [0, 0],
#  '0|1': [1, 0],
#  '1|1': [2, 0],
#  '1|0': [3, 0],
#  '2|0': [4, 0],
#  '3|0': [5, 0],
#  '3|1': [6, 0],
#  '2|1': [7, 0],
#  '2|2': [8, 0],
#  '3|2': [9, 0],
#  '3|3': [10, 0],
#  '2|3': [11, 0],
#  '1|3': [12, 0],
#  '1|2': [13, 0],
#  '0|2': [14, 0],
#  '0|3': [15, 0],
#  '0|4': [16, 0],
#  '1|4': [17, 0],
#  '1|5': [18, 0],
#  '0|5': [19, 0],
#  '0|6': [20, 0],
#  '0|7': [21, 0],
#  '1|7': [22, 0],
#  '1|6': [23, 0],
#  '2|6': [24, 0],
#  '2|7': [25, 0],
#  '3|7': [26, 0],
#  '3|6': [27, 0],
#  '3|5': [28, 0],
#  '2|5': [29, 0],
#  '2|4': [30, 0],
#  '3|4': [31, 0],
#  '4|4': [32, 0],
#  '5|4': [33, 0],
#  '5|5': [34, 0],
#  '4|5': [35, 0],
#  '4|6': [36, 0],
#  '4|7': [37, 0],
#  '5|7': [38, 0],
#  '5|6': [39, 0],
#  '6|6': [40, 0],
#  '6|7': [41, 0],
#  '7|7': [42, 0],
#  '7|6': [43, 0],
#  '7|5': [44, 0],
#  '6|5': [45, 0],
#  '6|4': [46, 0],
#  '7|4': [47, 0],
#  '7|3': [48, 0],
#  '7|2': [49, 0],
#  '6|2': [50, 0],
#  '6|3': [51, 0],
#  '5|3': [52, 0],
#  '4|3': [53, 0],
#  '4|2': [54, 0],
#  '5|2': [55, 0],
#  '5|1': [56, 0],
#  '4|1': [57, 0],
#  '4|0': [58, 0],
#  '5|0': [59, 0],
#  '6|0': [60, 0],
#  '6|1': [61, 0],
#  '7|1': [62, 0],
#  '7|0': [63, 0],
#  '8|0': [64, 0],
#  '9|0': [65, 0],
#  '9|1': [66, 0],
#  '8|1': [67, 0],
#  '8|2': [68, 0],
#  '8|3': [69, 0],
#  '9|3': [70, 0],
#  '9|2': [71, 0],
#  '10|2': [72, 0],
#  '10|3': [73, 0],
#  '11|3': [74, 0],
#  '11|2': [75, 0],
#  '11|1': [76, 0],
#  '10|1': [77, 0],
#  '10|0': [78, 0],
#  '11|0': [79, 0],
#  '12|0': [80, 0],
#  '12|1': [81, 0],
#  '13|1': [82, 0],
#  '13|0': [83, 0],
#  '14|0': [84, 0],
#  '15|0': [85, 0],
#  '15|1': [86, 0],
#  '14|1': [87, 0],
#  '14|2': [88, 0],
#  '15|2': [89, 0],
#  '15|3': [90, 0],
#  '14|3': [91, 0],
#  '13|3': [92, 0],
#  '13|2': [93, 0],
#  '12|2': [94, 0],
#  '12|3': [95, 0],
#  '12|4': [96, 0],
#  '12|5': [97, 0],
#  '13|5': [98, 0],
#  '13|4': [99, 0],
#  '14|4': [100, 0],
#  '15|4': [101, 0],
#  '15|5': [102, 0],
#  '14|5': [103, 0],
#  '14|6': [104, 0],
#  '15|6': [105, 0],
#  '15|7': [106, 0],
#  '14|7': [107, 0],
#  '13|7': [108, 0],
#  '13|6': [109, 0],
#  '12|6': [110, 0],
#  '12|7': [111, 0],
#  '11|7': [112, 0],
#  '10|7': [113, 0],
#  '10|6': [114, 0],
#  '11|6': [115, 0],
#  '11|5': [116, 0],
#  '11|4': [117, 0],
#  '10|4': [118, 0],
#  '10|5': [119, 0],
#  '9|5': [120, 0],
#  '9|4': [121, 0],
#  '8|4': [122, 0],
#  '8|5': [123, 0],
#  '8|6': [124, 0],
#  '9|6': [125, 0],
#  '9|7': [126, 0],
#  '8|7': [127, 0],
#  '8|8': [128, 0],
#  '9|8': [129, 0],
#  '9|9': [130, 0],
#  '8|9': [131, 0],
#  '8|10': [132, 0],
#  '8|11': [133, 0],
#  '9|11': [134, 0],
#  '9|10': [135, 0],
#  '10|10': [136, 0],
#  '10|11': [137, 0],
#  '11|11': [138, 0],
#  '11|10': [139, 0],
#  '11|9': [140, 0],
#  '10|9': [141, 0],
#  '10|8': [142, 0],
#  '11|8': [143, 0],
#  '12|8': [144, 0],
#  '12|9': [145, 0],
#  '13|9': [146, 0],
#  '13|8': [147, 0],
#  '14|8': [148, 0],
#  '15|8': [149, 0],
#  '15|9': [150, 0],
#  '14|9': [151, 0],
#  '14|10': [152, 0],
#  '15|10': [153, 0],
#  '15|11': [154, 0],
#  '14|11': [155, 0],
#  '13|11': [156, 0],
#  '13|10': [157, 0],
#  '12|10': [158, 0],
#  '12|11': [159, 0],
#  '12|12': [160, 0],
#  '12|13': [161, 0],
#  '13|13': [162, 0],
#  '13|12': [163, 0],
#  '14|12': [164, 0],
#  '15|12': [165, 0],
#  '15|13': [166, 0],
#  '14|13': [167, 0],
#  '14|14': [168, 0],
#  '15|14': [169, 0],
#  '15|15': [170, 0],
#  '14|15': [171, 0],
#  '13|15': [172, 0],
#  '13|14': [173, 0],
#  '12|14': [174, 0],
#  '12|15': [175, 0],
#  '11|15': [176, 0],
#  '10|15': [177, 0],
#  '10|14': [178, 0],
#  '11|14': [179, 0],
#  '11|13': [180, 0],
#  '11|12': [181, 0],
#  '10|12': [182, 0],
#  '10|13': [183, 0],
#  '9|13': [184, 0],
#  '9|12': [185, 0],
#  '8|12': [186, 0],
#  '8|13': [187, 0],
#  '8|14': [188, 0],
#  '9|14': [189, 0],
#  '9|15': [190, 0],
#  '8|15': [191, 0],
#  '7|15': [192, 0],
#  '7|14': [193, 0],
#  '6|14': [194, 0],
#  '6|15': [195, 0],
#  '5|15': [196, 0],
#  '4|15': [197, 0],
#  '4|14': [198, 0],
#  '5|14': [199, 0],
#  '5|13': [200, 0],
#  '4|13': [201, 0],
#  '4|12': [202, 0],
#  '5|12': [203, 0],
#  '6|12': [204, 0],
#  '6|13': [205, 0],
#  '7|13': [206, 0],
#  '7|12': [207, 0],
#  '7|11': [208, 0],
#  '6|11': [209, 0],
#  '6|10': [210, 0],
#  '7|10': [211, 0],
#  '7|9': [212, 0],
#  '7|8': [213, 0],
#  '6|8': [214, 0],
#  '6|9': [215, 0],
#  '5|9': [216, 0],
#  '5|8': [217, 0],
#  '4|8': [218, 0],
#  '4|9': [219, 0],
#  '4|10': [220, 0],
#  '5|10': [221, 0],
#  '5|11': [222, 0],
#  '4|11': [223, 0],
#  '3|11': [224, 0],
#  '2|11': [225, 0],
#  '2|10': [226, 0],
#  '3|10': [227, 0],
#  '3|9': [228, 0],
#  '3|8': [229, 0],
#  '2|8': [230, 0],
#  '2|9': [231, 0],
#  '1|9': [232, 0],
#  '1|8': [233, 0],
#  '0|8': [234, 0],
#  '0|9': [235, 0],
#  '0|10': [236, 0],
#  '1|10': [237, 0],
#  '1|11': [238, 0],
#  '0|11': [239, 0],
#  '0|12': [240, 0],
#  '0|13': [241, 0],
#  '1|13': [242, 0],
#  '1|12': [243, 0],
#  '2|12': [244, 0],
#  '3|12': [245, 0],
#  '3|13': [246, 0],
#  '2|13': [247, 0],
#  '2|14': [248, 0],
#  '3|14': [249, 0],
#  '3|15': [250, 0],
#  '2|15': [251, 0],
#  '1|15': [252, 0],
#  '1|14': [253, 0],
#  '0|14': [254, 0],
#  '0|15': [255, 0],
#  '0|16': [256, 0],
#  '1|16': [257, 0],
#  '1|17': [258, 0],
#  '0|17': [259, 0],
#  '0|18': [260, 0],
#  '0|19': [261, 0],
#  '1|19': [262, 0],
#  '1|18': [263, 0],
#  '2|18': [264, 0],
#  '2|19': [265, 0],
#  '3|19': [266, 0],
#  '3|18': [267, 0],
#  '3|17': [268, 0],
#  '2|17': [269, 0],
#  '2|16': [270, 0],
#  '3|16': [271, 0],
#  '4|16': [272, 0],
#  '4|17': [273, 0],
#  '5|17': [274, 0],
#  '5|16': [275, 0],
#  '6|16': [276, 0],
#  '7|16': [277, 0],
#  '7|17': [278, 0],
#  '6|17': [279, 0],
#  '6|18': [280, 0],
#  '7|18': [281, 0],
#  '7|19': [282, 0],
#  '6|19': [283, 0],
#  '5|19': [284, 0],
#  '5|18': [285, 0],
#  '4|18': [286, 0],
#  '4|19': [287, 0],
#  '4|20': [288, 0],
#  '4|21': [289, 0],
#  '5|21': [290, 0],
#  '5|20': [291, 0],
#  '6|20': [292, 0],
#  '7|20': [293, 0],
#  '7|21': [294, 0],
#  '6|21': [295, 0],
#  '6|22': [296, 0],
#  '7|22': [297, 0],
#  '7|23': [298, 0],
#  '6|23': [299, 0],
#  '5|23': [300, 0],
#  '5|22': [301, 0],
#  '4|22': [302, 0],
#  '4|23': [303, 0],
#  '3|23': [304, 0],
#  '2|23': [305, 0],
#  '2|22': [306, 0],
#  '3|22': [307, 0],
#  '3|21': [308, 0],
#  '3|20': [309, 0],
#  '2|20': [310, 0],
#  '2|21': [311, 0],
#  '1|21': [312, 0],
#  '1|20': [313, 0],
#  '0|20': [314, 0],
#  '0|21': [315, 0],
#  '0|22': [316, 0],
#  '1|22': [317, 0],
#  '1|23': [318, 0],
#  '0|23': [319, 0],
#  '0|24': [320, 0],
#  '0|25': [321, 0],
#  '1|25': [322, 0],
#  '1|24': [323, 0],
#  '2|24': [324, 0],
#  '3|24': [325, 0],
#  '3|25': [326, 0],
#  '2|25': [327, 0],
#  '2|26': [328, 0],
#  '3|26': [329, 0],
#  '3|27': [330, 0],
#  '2|27': [331, 0],
#  '1|27': [332, 0],
#  '1|26': [333, 0],
#  '0|26': [334, 0],
#  '0|27': [335, 0],
#  '0|28': [336, 0],
#  '1|28': [337, 0],
#  '1|29': [338, 0],
#  '0|29': [339, 0],
#  '0|30': [340, 0],
#  '0|31': [341, 0],
#  '1|31': [342, 0],
#  '1|30': [343, 0],
#  '2|30': [344, 0],
#  '2|31': [345, 0],
#  '3|31': [346, 0],
#  '3|30': [347, 0],
#  '3|29': [348, 0],
#  '2|29': [349, 0],
#  '2|28': [350, 0],
#  '3|28': [351, 0],
#  '4|28': [352, 0],
#  '5|28': [353, 0],
#  '5|29': [354, 0],
#  '4|29': [355, 0],
#  '4|30': [356, 0],
#  '4|31': [357, 0],
#  '5|31': [358, 0],
#  '5|30': [359, 0],
#  '6|30': [360, 0],
#  '6|31': [361, 0],
#  '7|31': [362, 0],
#  '7|30': [363, 0],
#  '7|29': [364, 0],
#  '6|29': [365, 0],
#  '6|28': [366, 0],
#  '7|28': [367, 0],
#  '7|27': [368, 0],
#  '7|26': [369, 0],
#  '6|26': [370, 0],
#  '6|27': [371, 0],
#  '5|27': [372, 0],
#  '4|27': [373, 0],
#  '4|26': [374, 0],
#  '5|26': [375, 0],
#  '5|25': [376, 0],
#  '4|25': [377, 0],
#  '4|24': [378, 0],
#  '5|24': [379, 0],
#  '6|24': [380, 0],
#  '6|25': [381, 0],
#  '7|25': [382, 0],
#  '7|24': [383, 0],
#  '8|24': [384, 0],
#  '8|25': [385, 0],
#  '9|25': [386, 0],
#  '9|24': [387, 0],
#  '10|24': [388, 0],
#  '11|24': [389, 0],
#  '11|25': [390, 0],
#  '10|25': [391, 0],
#  '10|26': [392, 0],
#  '11|26': [393, 0],
#  '11|27': [394, 0],
#  '10|27': [395, 0],
#  '9|27': [396, 0],
#  '9|26': [397, 0],
#  '8|26': [398, 0],
#  '8|27': [399, 0],
#  '8|28': [400, 0],
#  '9|28': [401, 0],
#  '9|29': [402, 0],
#  '8|29': [403, 0],
#  '8|30': [404, 0],
#  '8|31': [405, 0],
#  '9|31': [406, 0],
#  '9|30': [407, 0],
#  '10|30': [408, 0],
#  '10|31': [409, 0],
#  '11|31': [410, 0],
#  '11|30': [411, 0],
#  '11|29': [412, 0],
#  '10|29': [413, 0],
#  '10|28': [414, 0],
#  '11|28': [415, 0],
#  '12|28': [416, 0],
#  '13|28': [417, 0],
#  '13|29': [418, 0],
#  '12|29': [419, 0],
#  '12|30': [420, 0],
#  '12|31': [421, 0],
#  '13|31': [422, 0],
#  '13|30': [423, 0],
#  '14|30': [424, 0],
#  '14|31': [425, 0],
#  '15|31': [426, 0],
#  '15|30': [427, 0],
#  '15|29': [428, 0],
#  '14|29': [429, 0],
#  '14|28': [430, 0],
#  '15|28': [431, 0],
#  '15|27': [432, 0],
#  '15|26': [433, 0],
#  '14|26': [434, 0],
#  '14|27': [435, 0],
#  '13|27': [436, 0],
#  '12|27': [437, 0],
#  '12|26': [438, 0],
#  '13|26': [439, 0],
#  '13|25': [440, 0],
#  '12|25': [441, 0],
#  '12|24': [442, 0],
#  '13|24': [443, 0],
#  '14|24': [444, 0],
#  '14|25': [445, 0],
#  '15|25': [446, 0],
#  '15|24': [447, 0],
#  '15|23': [448, 0],
#  '14|23': [449, 0],
#  '14|22': [450, 0],
#  '15|22': [451, 0],
#  '15|21': [452, 0],
#  '15|20': [453, 0],
#  '14|20': [454, 0],
#  '14|21': [455, 0],
#  '13|21': [456, 0],
#  '13|20': [457, 0],
#  '12|20': [458, 0],
#  '12|21': [459, 0],
#  '12|22': [460, 0],
#  '13|22': [461, 0],
#  '13|23': [462, 0],
#  '12|23': [463, 0],
#  '11|23': [464, 0],
#  '11|22': [465, 0],
#  '10|22': [466, 0],
#  '10|23': [467, 0],
#  '9|23': [468, 0],
#  '8|23': [469, 0],
#  '8|22': [470, 0],
#  '9|22': [471, 0],
#  '9|21': [472, 0],
#  '8|21': [473, 0],
#  '8|20': [474, 0],
#  '9|20': [475, 0],
#  '10|20': [476, 0],
#  '10|21': [477, 0],
#  '11|21': [478, 0],
#  '11|20': [479, 0],
#  '11|19': [480, 0],
#  '11|18': [481, 0],
#  '10|18': [482, 0],
#  '10|19': [483, 0],
#  '9|19': [484, 0],
#  '8|19': [485, 0],
#  '8|18': [486, 0],
#  '9|18': [487, 0],
#  '9|17': [488, 0],
#  '8|17': [489, 0],
#  '8|16': [490, 0],
#  '9|16': [491, 0],
#  '10|16': [492, 0],
#  '10|17': [493, 0],
#  '11|17': [494, 0],
#  '11|16': [495, 0],
#  '12|16': [496, 0],
#  '13|16': [497, 0],
#  '13|17': [498, 0],
#  '12|17': [499, 0],
#  '12|18': [500, 0],
#  '12|19': [501, 0],
#  '13|19': [502, 0],
#  '13|18': [503, 0],
#  '14|18': [504, 0],
#  '14|19': [505, 0],
#  '15|19': [506, 0],
#  '15|18': [507, 0],
#  '15|17': [508, 0],
#  '14|17': [509, 0],
#  '14|16': [510, 0],
#  '15|16': [511, 0],
#  '16|16': [512, 0],
#  '17|16': [513, 0],
#  '17|17': [514, 0],
#  '16|17': [515, 0],
#  '16|18': [516, 0],
#  '16|19': [517, 0],
#  '17|19': [518, 0],
#  '17|18': [519, 0],
#  '18|18': [520, 0],
#  '18|19': [521, 0],
#  '19|19': [522, 0],
#  '19|18': [523, 0],
#  '19|17': [524, 0],
#  '18|17': [525, 0],
#  '18|16': [526, 0],
#  '19|16': [527, 0],
#  '20|16': [528, 0],
#  '20|17': [529, 0],
#  '21|17': [530, 0],
#  '21|16': [531, 0],
#  '22|16': [532, 0],
#  '23|16': [533, 0],
#  '23|17': [534, 0],
#  '22|17': [535, 0],
#  '22|18': [536, 0],
#  '23|18': [537, 0],
#  '23|19': [538, 0],
#  '22|19': [539, 0],
#  '21|19': [540, 0],
#  '21|18': [541, 0],
#  '20|18': [542, 0],
#  '20|19': [543, 0],
#  '20|20': [544, 0],
#  '20|21': [545, 0],
#  '21|21': [546, 0],
#  '21|20': [547, 0],
#  '22|20': [548, 0],
#  '23|20': [549, 0],
#  '23|21': [550, 0],
#  '22|21': [551, 0],
#  '22|22': [552, 0],
#  '23|22': [553, 0],
#  '23|23': [554, 0],
#  '22|23': [555, 0],
#  '21|23': [556, 0],
#  '21|22': [557, 0],
#  '20|22': [558, 0],
#  '20|23': [559, 0],
#  '19|23': [560, 0],
#  '18|23': [561, 0],
#  '18|22': [562, 0],
#  '19|22': [563, 0],
#  '19|21': [564, 0],
#  '19|20': [565, 0],
#  '18|20': [566, 0],
#  '18|21': [567, 0],
#  '17|21': [568, 0],
#  '17|20': [569, 0],
#  '16|20': [570, 0],
#  '16|21': [571, 0],
#  '16|22': [572, 0],
#  '17|22': [573, 0],
#  '17|23': [574, 0],
#  '16|23': [575, 0],
#  '16|24': [576, 0],
#  '16|25': [577, 0],
#  '17|25': [578, 0],
#  '17|24': [579, 0],
#  '18|24': [580, 0],
#  '19|24': [581, 0],
#  '19|25': [582, 0],
#  '18|25': [583, 0],
#  '18|26': [584, 0],
#  '19|26': [585, 0],
#  '19|27': [586, 0],
#  '18|27': [587, 0],
#  '17|27': [588, 0],
#  '17|26': [589, 0],
#  '16|26': [590, 0],
#  '16|27': [591, 0],
#  '16|28': [592, 0],
#  '17|28': [593, 0],
#  '17|29': [594, 0],
#  '16|29': [595, 0],
#  '16|30': [596, 0],
#  '16|31': [597, 0],
#  '17|31': [598, 0],
#  '17|30': [599, 0],
#  '18|30': [600, 0],
#  '18|31': [601, 0],
#  '19|31': [602, 0],
#  '19|30': [603, 0],
#  '19|29': [604, 0],
#  '18|29': [605, 0],
#  '18|28': [606, 0],
#  '19|28': [607, 0],
#  '20|28': [608, 0],
#  '21|28': [609, 0],
#  '21|29': [610, 0],
#  '20|29': [611, 0],
#  '20|30': [612, 0],
#  '20|31': [613, 0],
#  '21|31': [614, 0],
#  '21|30': [615, 0],
#  '22|30': [616, 0],
#  '22|31': [617, 0],
#  '23|31': [618, 0],
#  '23|30': [619, 0],
#  '23|29': [620, 0],
#  '22|29': [621, 0],
#  '22|28': [622, 0],
#  '23|28': [623, 0],
#  '23|27': [624, 0],
#  '23|26': [625, 0],
#  '22|26': [626, 0],
#  '22|27': [627, 0],
#  '21|27': [628, 0],
#  '20|27': [629, 0],
#  '20|26': [630, 0],
#  '21|26': [631, 0],
#  '21|25': [632, 0],
#  '20|25': [633, 0],
#  '20|24': [634, 0],
#  '21|24': [635, 0],
#  '22|24': [636, 0],
#  '22|25': [637, 0],
#  '23|25': [638, 0],
#  '23|24': [639, 0],
#  '24|24': [640, 0],
#  '24|25': [641, 0],
#  '25|25': [642, 0],
#  '25|24': [643, 0],
#  '26|24': [644, 0],
#  '27|24': [645, 0],
#  '27|25': [646, 0],
#  '26|25': [647, 0],
#  '26|26': [648, 0],
#  '27|26': [649, 0],
#  '27|27': [650, 0],
#  '26|27': [651, 0],
#  '25|27': [652, 0],
#  '25|26': [653, 0],
#  '24|26': [654, 0],
#  '24|27': [655, 0],
#  '24|28': [656, 0],
#  '25|28': [657, 0],
#  '25|29': [658, 0],
#  '24|29': [659, 0],
#  '24|30': [660, 0],
#  '24|31': [661, 0],
#  '25|31': [662, 0],
#  '25|30': [663, 0],
#  '26|30': [664, 0],
#  '26|31': [665, 0],
#  '27|31': [666, 0],
#  '27|30': [667, 0],
#  '27|29': [668, 0],
#  '26|29': [669, 0],
#  '26|28': [670, 0],
#  '27|28': [671, 0],
#  '28|28': [672, 0],
#  '29|28': [673, 0],
#  '29|29': [674, 0],
#  '28|29': [675, 0],
#  '28|30': [676, 0],
#  '28|31': [677, 0],
#  '29|31': [678, 0],
#  '29|30': [679, 0],
#  '30|30': [680, 0],
#  '30|31': [681, 0],
#  '31|31': [682, 0],
#  '31|30': [683, 0],
#  '31|29': [684, 0],
#  '30|29': [685, 0],
#  '30|28': [686, 0],
#  '31|28': [687, 0],
#  '31|27': [688, 0],
#  '31|26': [689, 0],
#  '30|26': [690, 0],
#  '30|27': [691, 0],
#  '29|27': [692, 0],
#  '28|27': [693, 0],
#  '28|26': [694, 0],
#  '29|26': [695, 0],
#  '29|25': [696, 0],
#  '28|25': [697, 0],
#  '28|24': [698, 0],
#  '29|24': [699, 0],
#  '30|24': [700, 0],
#  '30|25': [701, 0],
#  '31|25': [702, 0],
#  '31|24': [703, 0],
#  '31|23': [704, 0],
#  '30|23': [705, 0],
#  '30|22': [706, 0],
#  '31|22': [707, 0],
#  '31|21': [708, 0],
#  '31|20': [709, 0],
#  '30|20': [710, 0],
#  '30|21': [711, 0],
#  '29|21': [712, 0],
#  '29|20': [713, 0],
#  '28|20': [714, 0],
#  '28|21': [715, 0],
#  '28|22': [716, 0],
#  '29|22': [717, 0],
#  '29|23': [718, 0],
#  '28|23': [719, 0],
#  '27|23': [720, 0],
#  '27|22': [721, 0],
#  '26|22': [722, 0],
#  '26|23': [723, 0],
#  '25|23': [724, 0],
#  '24|23': [725, 0],
#  '24|22': [726, 0],
#  '25|22': [727, 0],
#  '25|21': [728, 0],
#  '24|21': [729, 0],
#  '24|20': [730, 0],
#  '25|20': [731, 0],
#  '26|20': [732, 0],
#  '26|21': [733, 0],
#  '27|21': [734, 0],
#  '27|20': [735, 0],
#  '27|19': [736, 0],
#  '27|18': [737, 0],
#  '26|18': [738, 0],
#  '26|19': [739, 0],
#  '25|19': [740, 0],
#  '24|19': [741, 0],
#  '24|18': [742, 0],
#  '25|18': [743, 0],
#  '25|17': [744, 0],
#  '24|17': [745, 0],
#  '24|16': [746, 0],
#  '25|16': [747, 0],
#  '26|16': [748, 0],
#  '26|17': [749, 0],
#  '27|17': [750, 0],
#  '27|16': [751, 0],
#  '28|16': [752, 0],
#  '29|16': [753, 0],
#  '29|17': [754, 0],
#  '28|17': [755, 0],
#  '28|18': [756, 0],
#  '28|19': [757, 0],
#  '29|19': [758, 0],
#  '29|18': [759, 0],
#  '30|18': [760, 0],
#  '30|19': [761, 0],
#  '31|19': [762, 0],
#  '31|18': [763, 0],
#  '31|17': [764, 0],
#  '30|17': [765, 0],
#  '30|16': [766, 0],
#  '31|16': [767, 0],
#  '31|15': [768, 0],
#  '31|14': [769, 0],
#  '30|14': [770, 0],
#  '30|15': [771, 0],
#  '29|15': [772, 0],
#  '28|15': [773, 0],
#  '28|14': [774, 0],
#  '29|14': [775, 0],
#  '29|13': [776, 0],
#  '28|13': [777, 0],
#  '28|12': [778, 0],
#  '29|12': [779, 0],
#  '30|12': [780, 0],
#  '30|13': [781, 0],
#  '31|13': [782, 0],
#  '31|12': [783, 0],
#  '31|11': [784, 0],
#  '30|11': [785, 0],
#  '30|10': [786, 0],
#  '31|10': [787, 0],
#  '31|9': [788, 0],
#  '31|8': [789, 0],
#  '30|8': [790, 0],
#  '30|9': [791, 0],
#  '29|9': [792, 0],
#  '29|8': [793, 0],
#  '28|8': [794, 0],
#  '28|9': [795, 0],
#  '28|10': [796, 0],
#  '29|10': [797, 0],
#  '29|11': [798, 0],
#  '28|11': [799, 0],
#  '27|11': [800, 0],
#  '26|11': [801, 0],
#  '26|10': [802, 0],
#  '27|10': [803, 0],
#  '27|9': [804, 0],
#  '27|8': [805, 0],
#  '26|8': [806, 0],
#  '26|9': [807, 0],
#  '25|9': [808, 0],
#  '25|8': [809, 0],
#  '24|8': [810, 0],
#  '24|9': [811, 0],
#  '24|10': [812, 0],
#  '25|10': [813, 0],
#  '25|11': [814, 0],
#  '24|11': [815, 0],
#  '24|12': [816, 0],
#  '24|13': [817, 0],
#  '25|13': [818, 0],
#  '25|12': [819, 0],
#  '26|12': [820, 0],
#  '27|12': [821, 0],
#  '27|13': [822, 0],
#  '26|13': [823, 0],
#  '26|14': [824, 0],
#  '27|14': [825, 0],
#  '27|15': [826, 0],
#  '26|15': [827, 0],
#  '25|15': [828, 0],
#  '25|14': [829, 0],
#  '24|14': [830, 0],
#  '24|15': [831, 0],
#  '23|15': [832, 0],
#  '22|15': [833, 0],
#  '22|14': [834, 0],
#  '23|14': [835, 0],
#  '23|13': [836, 0],
#  '23|12': [837, 0],
#  '22|12': [838, 0],
#  '22|13': [839, 0],
#  '21|13': [840, 0],
#  '21|12': [841, 0],
#  '20|12': [842, 0],
#  '20|13': [843, 0],
#  '20|14': [844, 0],
#  '21|14': [845, 0],
#  '21|15': [846, 0],
#  '20|15': [847, 0],
#  '19|15': [848, 0],
#  '19|14': [849, 0],
#  '18|14': [850, 0],
#  '18|15': [851, 0],
#  '17|15': [852, 0],
#  '16|15': [853, 0],
#  '16|14': [854, 0],
#  '17|14': [855, 0],
#  '17|13': [856, 0],
#  '16|13': [857, 0],
#  '16|12': [858, 0],
#  '17|12': [859, 0],
#  '18|12': [860, 0],
#  '18|13': [861, 0],
#  '19|13': [862, 0],
#  '19|12': [863, 0],
#  '19|11': [864, 0],
#  '19|10': [865, 0],
#  '18|10': [866, 0],
#  '18|11': [867, 0],
#  '17|11': [868, 0],
#  '16|11': [869, 0],
#  '16|10': [870, 0],
#  '17|10': [871, 0],
#  '17|9': [872, 0],
#  '16|9': [873, 0],
#  '16|8': [874, 0],
#  '17|8': [875, 0],
#  '18|8': [876, 0],
#  '18|9': [877, 0],
#  '19|9': [878, 0],
#  '19|8': [879, 0],
#  '20|8': [880, 0],
#  '21|8': [881, 0],
#  '21|9': [882, 0],
#  '20|9': [883, 0],
#  '20|10': [884, 0],
#  '20|11': [885, 0],
#  '21|11': [886, 0],
#  '21|10': [887, 0],
#  '22|10': [888, 0],
#  '22|11': [889, 0],
#  '23|11': [890, 0],
#  '23|10': [891, 0],
#  '23|9': [892, 0],
#  '22|9': [893, 0],
#  '22|8': [894, 0],
#  '23|8': [895, 0],
#  '23|7': [896, 0],
#  '22|7': [897, 0],
#  '22|6': [898, 0],
#  '23|6': [899, 0],
#  '23|5': [900, 0],
#  '23|4': [901, 0],
#  '22|4': [902, 0],
#  '22|5': [903, 0],
#  '21|5': [904, 0],
#  '21|4': [905, 0],
#  '20|4': [906, 0],
#  '20|5': [907, 0],
#  '20|6': [908, 0],
#  '21|6': [909, 0],
#  '21|7': [910, 0],
#  '20|7': [911, 0],
#  '19|7': [912, 0],
#  '19|6': [913, 0],
#  '18|6': [914, 0],
#  '18|7': [915, 0],
#  '17|7': [916, 0],
#  '16|7': [917, 0],
#  '16|6': [918, 0],
#  '17|6': [919, 0],
#  '17|5': [920, 0],
#  '16|5': [921, 0],
#  '16|4': [922, 0],
#  '17|4': [923, 0],
#  '18|4': [924, 0],
#  '18|5': [925, 0],
#  '19|5': [926, 0],
#  '19|4': [927, 0],
#  '19|3': [928, 0],
#  '19|2': [929, 0],
#  '18|2': [930, 0],
#  '18|3': [931, 0],
#  '17|3': [932, 0],
#  '16|3': [933, 0],
#  '16|2': [934, 0],
#  '17|2': [935, 0],
#  '17|1': [936, 0],
#  '16|1': [937, 0],
#  '16|0': [938, 0],
#  '17|0': [939, 0],
#  '18|0': [940, 0],
#  '18|1': [941, 0],
#  '19|1': [942, 0],
#  '19|0': [943, 0],
#  '20|0': [944, 0],
#  '21|0': [945, 0],
#  '21|1': [946, 0],
#  '20|1': [947, 0],
#  '20|2': [948, 0],
#  '20|3': [949, 0],
#  '21|3': [950, 0],
#  '21|2': [951, 0],
#  '22|2': [952, 0],
#  '22|3': [953, 0],
#  '23|3': [954, 0],
#  '23|2': [955, 0],
#  '23|1': [956, 0],
#  '22|1': [957, 0],
#  '22|0': [958, 0],
#  '23|0': [959, 0],
#  '24|0': [960, 0],
#  '24|1': [961, 0],
#  '25|1': [962, 0],
#  '25|0': [963, 0],
#  '26|0': [964, 0],
#  '27|0': [965, 0],
#  '27|1': [966, 0],
#  '26|1': [967, 0],
#  '26|2': [968, 0],
#  '27|2': [969, 0],
#  '27|3': [970, 0],
#  '26|3': [971, 0],
#  '25|3': [972, 0],
#  '25|2': [973, 0],
#  '24|2': [974, 0],
#  '24|3': [975, 0],
#  '24|4': [976, 0],
#  '25|4': [977, 0],
#  '25|5': [978, 0],
#  '24|5': [979, 0],
#  '24|6': [980, 0],
#  '24|7': [981, 0],
#  '25|7': [982, 0],
#  '25|6': [983, 0],
#  '26|6': [984, 0],
#  '26|7': [985, 0],
#  '27|7': [986, 0],
#  '27|6': [987, 0],
#  '27|5': [988, 0],
#  '26|5': [989, 0],
#  '26|4': [990, 0],
#  '27|4': [991, 0],
#  '28|4': [992, 0],
#  '29|4': [993, 0],
#  '29|5': [994, 0],
#  '28|5': [995, 0],
#  '28|6': [996, 0],
#  '28|7': [997, 0],
#  '29|7': [998, 0],
#  '29|6': [999, 0],
#  ...}

# %%
# Out:
# 16.0

# %%
#take an idividual place (x,y) & find the closest places and weigh
width=20#min of 0 max of width-1
height=20#min of 0 max of height-1
x=18.99999999999
y=19

x0=(WidthAndHeight-1)*x/(width-1)
y0=(WidthAndHeight-1)*x/(height-1)

x1=math.ceil(x0)
x2=math.floor(x0)

y1=math.ceil(y0)
y2=math.floor(y0)

xs=[x1,x2]
ys=[y1,y2]

#make the lists
#Determine lengths
lists={}
for xval in range(len(xs)):
    for yval in range(len(ys)):
        lists["x"+str(xval+1)+"y"+str(yval+1)]=(((x0-xs[xval])**2+(y0-ys[yval])**2)**2)

#get the one over the value:
for xval in range(len(xs)):
    for yval in range(len(ys)):
        if lists["x"+str(xval+1)+"y"+str(yval+1)]==0:#check to prevent dividing by zero
            lists["x"+str(xval+1)+"y"+str(yval+1)]=10000000000000000000
        else:
            lists["x"+str(xval+1)+"y"+str(yval+1)]=1/lists["x"+str(xval+1)+"y"+str(yval+1)]
        
        
#now determine the different multipliers
m=0
for taco in lists:#m is the average
    m+=lists[taco]
m=m/len(lists)

for taco in lists:#now you shrink the values
    lists[taco]=lists[taco]/m
#all of the values of x's & y's in lists are the multiplier for the values of original x & y that you then add 

#now determine the lengths and then the 
print(lists)
print(m)
# Out:
# {'x1y1': 4.0, 'x1y2': 6.219105064240392e-44, 'x2y1': 6.219105064240392e-44, 'x2y2': 1.554776266060098e-44}
# 1.6079483940246387e+43
